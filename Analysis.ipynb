# %% [markdown]
# <a href="https://colab.research.google.com/github/espseongsm/streaming_stock_prices_and_analyzing_in_AWS/blob/master/Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Here is my analysis by jupyter notebook. The target is when is the highest values at May 14th,2020.

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/espseongsm/streaming_stock_prices_and_analyzing_in_AWS/master/results.csv'
df1 = pd.read_csv(url)

# %%
import matplotlib.pyplot as plt
df1.plot(title ="Top Categories by Business", figsize=(15, 10), legend=True, fontsize=8, x = 'Hour')
# %matplot plt
# Out:
# UsageError: Line magic function `%matplot` not found.

# %% [markdown]
# There is no significant difference at May 14th, 2020; however, all the srock price is peak around 11 am.
